# %%
#@title Import requirements
# !pip install numpy
# !pip install pyvirtualdisplay gymnasium

import base64
from pathlib import Path

from gymnasium.wrappers import RecordVideo
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display


import sys


# Get the parent directory of the current Jupyter notebook's directory


parent_dir = Path().resolve().parent

# Construct the path to the 'rl-agents' folder
rl_agents_dir = parent_dir / 'rl-agents'

# Add the 'rl-agents' directory to sys.path
sys.path.append(str(rl_agents_dir))



import highway_env

highway_env.register_highway_envs()



# Environment

import gymnasium as gym
# !dir 
# !cd PettingZooSim\rl-agents

# Agent


# Visualisation utils
# !pip install moviepy


# !pip install imageio_ffmpeg tensorboard 
import sys
# %load_ext tensorboard
# !pip install tensorboardx gym pyvirtualdisplay tensorboard
sys.path.insert(0, '/HighwayEnv/scripts/')
def show_videos(path="videos"):
    html = []
    for mp4 in Path(path).glob("*.mp4"):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                      loop controls style="height: 400px;">
                      <source src="data:video/mp4;base64,{}" type="video/mp4" />
                 </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: numpy in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: pyvirtualdisplay in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (3.0)
# Requirement already satisfied: gymnasium in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from gymnasium) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from gymnasium) (0.0.4)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#  Volume in drive C is OS
#  Volume Serial Number is F219-1D4E
#
#  Directory of c:\Users\jimmy\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\HighwayEnv
#
# 17/04/2024  21:43    <DIR>          .
# 17/04/2024  21:21    <DIR>          ..
# 12/04/2024  21:09             2,175 .gitignore
# 12/04/2024  21:09               699 .pre-commit-config.yaml
# 12/04/2024  21:09               299 CITATION.cff
# 12/04/2024  21:09               138 codecov.yml
# 17/04/2024  21:21    <DIR>          docs
# 17/04/2024  21:59         2,272,217 eval.ipynb
# 17/04/2024  21:21    <DIR>          highway_env
# 12/04/2024  21:10               902 iridis2.py
# 17/04/2024  21:21    <DIR>          iridisResult
# 12/04/2024  21:09             1,093 LICENSE
# 17/04/2024  21:43    <DIR>          out
# 12/04/2024  21:09               108 pyproject.toml
# 12/04/2024  21:09            14,823 README.md
# 12/04/2024  21:09           363,307 runningStuff3.ipynb
# 12/04/2024  21:09         1,315,929 runningStuff4.ipynb
# 12/04/2024  21:10           244,212 runningStuff5.ipynb
# 12/04/2024  21:09           661,653 runningStuff6.ipynb
# 17/04/2024  21:21    <DIR>          scripts
# 12/04/2024  21:09               989 setup.cfg
# 12/04/2024  21:09               762 setup.py
# 12/04/2024  21:10                92 submitMe.slurm
# 17/04/2024  21:21    <DIR>          tests
# 12/04/2024  21:09                 0 __init__.py
#               17 File(s)      4,879,398 bytes
#                8 Dir(s)  82,498,777,088 bytes free
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: moviepy in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from moviepy) (4.66.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from moviepy) (1.26.4)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from moviepy) (2.34.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from moviepy) (0.4.9)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from imageio<3.0,>=2.5->moviepy) (10.3.0)
# Requirement already satisfied: setuptools in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from imageio-ffmpeg>=0.2.0->moviepy) (69.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\jimmy\appdata\roaming\python\python312\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.6)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: imageio_ffmpeg in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (0.4.9)
# Requirement already satisfied: tensorboard in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (2.16.2)
# Requirement already satisfied: setuptools in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from imageio_ffmpeg) (69.5.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (1.62.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (5.26.1)
# Requirement already satisfied: six>1.9 in c:\users\jimmy\appdata\roaming\python\python312\site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tensorboardx in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (2.6.2.2)
# Requirement already satisfied: gym in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (0.26.2)
# Requirement already satisfied: pyvirtualdisplay in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (3.0)
# Requirement already satisfied: tensorboard in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (2.16.2)
# Requirement already satisfied: numpy in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboardx) (1.26.4)
# Requirement already satisfied: packaging in c:\users\jimmy\appdata\roaming\python\python312\site-packages (from tensorboardx) (23.2)
# Requirement already satisfied: protobuf>=3.20 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboardx) (5.26.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from gym) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: absl-py>=0.4 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (1.62.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (3.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (69.5.1)
# Requirement already satisfied: six>1.9 in c:\users\jimmy\appdata\roaming\python\python312\site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jimmy\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#@title Prepare environment, agent, and evaluation process.


import sys


# Get the parent directory of the current Jupyter notebook's directory
parent_dir = Path().resolve().parent

# Construct the path to the 'rl-agents' folder
rl_agents_dir = parent_dir / 'rl-agents'

# Add the 'rl-agents' directory to sys.path
sys.path.append(str(rl_agents_dir))


from rl_agents.trainer.evaluation import Evaluation
from rl_agents.agents.common.factory import load_agent, load_environment

# Get the environment and agent configurations from the rl-agents repository


env_config = '../rl-agents/scripts/configs/IntersectionEnv/env_3way_int.json'
agent_config = '../rl-agents/scripts/configs/IntersectionEnv/agents/DQNAgent/ego_attention_8h.json'

env = load_environment(env_config)
env.config["offscreen_rendering"] = True


agent = load_agent(agent_config, env)
#iridisResult/run_20240406-191837_276956\checkpoint-best.tar
#run_20240406-192450_144391/checkpoint-best.tar
#run_20240406-192723_107405/checkpoint-best.tar

agent.load("iridisResult/run_20240409-134327_240459/checkpoint-best.tar")
#PettingZooSim\HighwayEnv\iridisResult\run_20240409-134327_240459\checkpoint-best.tar
# PettingZooSim\HighwayEnv\iridisResult\run_20240409-134327_240459\checkpoint-final.tar
agent.eval()
# Out:
# Absolute True
# Cheicvle count 15
# Final obs [[ 1.00000000e+00  1.56400745e+00  1.03774188e+00 -3.75895784e+00
#   -2.60679752e+00 -8.21737466e-01 -5.69866244e-01]
#  [ 1.00000000e+00 -5.02003205e+01  2.00000000e+00  9.59294963e+00
#   -1.97385811e-15  1.00000000e+00 -2.05761334e-16]
#  [ 1.00000000e+00 -8.36993331e+01  2.00000000e+00  9.16782938e+00
#   -1.88638480e-15  1.00000000e+00 -2.05761334e-16]
#  [ 1.00000000e+00  5.71484003e+01 -2.00000000e+00 -8.77390361e+00
#    1.07449330e-15 -1.00000000e+00  1.22464680e-16]
#  [ 1.00000000e+00 -6.89560658e+01  6.00000000e+00  8.81001285e+00
#   -1.85188431e-15  1.00000000e+00 -2.10202226e-16]
#  [ 1.00000000e+00  8.09482354e+01 -6.00000000e+00 -7.39894674e+00
#    9.06109644e-16 -1.00000000e+00  1.22464680e-16]
#  [ 1.00000000e+00 -2.35727254e+01  1.00000000e+01  8.03643438e+00
#   -1.61789852e-15  1.00000000e+00 -2.01320442e-16]
#  [ 1.00000000e+00  3.57890710e+01 -1.00000000e+01 -7.97981599e+00
#    4.52099579e-15 -1.00000000e+00  5.66553890e-16]
#  [ 1.00000000e+00  6.00000000e+00  1.77265999e+01  4.18241588e-16
#   -6.83040347e+00  6.12323400e-17 -1.00000000e+00]
#  [ 1.00000000e+00 -6.00000000e+00 -2.81502305e+01  3.39595880e-15
#    6.72039180e+00  5.05321550e-16  1.00000000e+00]
#  [ 1.00000000e+00  1.00000000e+01  4.28060784e+01  5.58190059e-16
#   -9.11593546e+00  6.12323400e-17 -1.00000000e+00]
#  [ 1.00000000e+00 -1.00000000
-01
#    2.22044605e-16 -1.00000000e+00  5.66553890e-16]
#  [ 1.00000000e+00 -1.15472994e-01  1.51371743e-01  3.17382492e-01
#    3.84210081e-01  6.36871375e-01  7.70970072e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# Observaton: [[ 1.00000000e+00  1.19071990e-01  2.07607392e-02  2.32056364e-01
#   -9.56632569e-02  9.24522817e-01 -3.81126672e-01]
#  [ 1.00000000e+00  5.99999987e-02  8.97540152e-01  0.00000000e+00
#   -4.25662011e-01  6.12323426e-17 -1.00000000e+00]
#  [ 1.00000000e+00 -8.23032737e-01  5.99999987e-02  4.20719892e-01
#    0.00000000e+00  1.00000000e+00 -2.10202224e-16]
#  [ 1.00000000e+00  6.78280354e-01 -5.99999987e-02 -4.40993667e-01
#    2.22044605e-16 -1.00000000e+00  5.66553869e-16]
#  [ 1.00000000e+00  1.99999996e-02  6.57331407e-01  0.00000000e+00
#   -4.33494806e-01  6.12323426e-17 -1.00000000e+00]
#  [ 1.00000000e+00  1.00000001e-01  4.70788419e-01  0.00000000e+00
#   -5.31806588e-01  6.12323426e-17 -1.00000000e+00]
#  [ 1.00000000e+00 -1.00000001e-01 -5.97235203e-01  0.00000000e+00
#    3.07549059e-01  2.83276934e-16  1.00000000e+00]
#  [ 1.00000000e+00  5.10737240e-01 -1.00000001e-01 -3.77600938e-01
#    2.22044605e-16 -1.00000000e+00  5.66553869e-16]
#  [ 1.00000000e+00  5.99999987e-02  2.90288717e-01  0.00000000e+00
#   -5.47852814e-01  6.12323426e-17 -1.00000000e+00]
#  [ 1.00000000e+00 -1.00000001e-01 -3.67625207e-01  2.22044605e-16
#    3.73407036e-01  5.05321539e-16  1.00000000e+00]
#  [ 1.00000000e+00 -3.04064065e-01  5.99999987e-02  4.46177483e-01
#   -2.22044605e-16  1.00000000e+00 -2.10202224e-16]
#  [ 1.00000000e+00  2.83701479e-01 -1.00000001e-01 -4.20183063e-01
#    2.22044605e-16 -1.00000000e+00  5.66553869e-16]
#  [ 1.00000000e+00 -1.15472995e-01  1.51371747e-01  3.17382485e-01
#    3.84210080e-01  6.36871397e-01  7.70970047e-01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]]
# The environment viewer doesn't support agent action rendering.
# INFO: Starting new video recorder writing to c:\Users\jimmy\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\HighwayEnv\out\ThreeWayIntersectionEnv\DQNAgent\run_20240417-223905_5144\rl-video-episode-0.mp4
# C:\Users\jimmy\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\rl-agents\rl_agents\agents\deep_q_network\pytorch.py:80: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:278.)
#   return self.value_net(torch.tensor(states, dtype=torch.float).to(self.device)).data.cpu().numpy()
# c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.observation_type to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.observation_type` for environment variables or `env.get_wrapper_attr('observation_type')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.road to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.road` for environment variables or `env.get_wrapper_attr('road')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.vehicle to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.vehicle` for environment variables or `env.get_wrapper_attr('vehicle')` that will search the reminding wrappers.
#   logger.warn(
# Absolute True
# Cheicvle count 15
# Normalizing
# Original df     presence          x          y            vx            vy         cos_h  \
# 0          1  15.053510  -0.889370  2.640638e+00 -2.410769e+00  7.385201e-01
# 1          1   6.000000  81.233227  5.222569e-16 -8.529103e+00  6.123234e-17
# 2          1 -73.885944   6.000000  8.420672e+00 -3.016554e-15  1.000000e+00
# 3          1  59.008164  -6.000000 -8.819873e+00  4.996933e-15 -1.000000e+00
# 4          1   2.000000  57.063244  5.308780e-16 -8.669896e+00  6.123234e-17
# 5          1  10.000000  36.442710  6.512752e-16 -1.063613e+01  6.123234e-17
# 6          1 -10.000000 -53.519189  3.163565e-15  6.260499e+00  5.053215e-16
# 7          1  43.464817 -10.000000 -7.669068e+00  4.344940e-15 -1.000000e+00
-01
#    0.00000000e+00 -1.00000000e+00  1.22464680e-16]]
# Time 4.0
# Truncated False
# Observaton: [[ 1.00000000e+00  1.10378630e-01  2.09102985e-02 -1.36801705e-01
#    3.33113164e-01  3.79888833e-01 -9.25032139e-01]
#  [ 1.00000000e+00  5.99999987e-02  5.52155137e-01  0.00000000e+00
#   -4.36199814e-01  6.12323426e-17 -1.00000000e+00]
#  [ 1.00000000e+00 -4.80443656e-01  5.99999987e-02  4.37597007e-01
#   -2.22044605e-16  1.00000000e+00 -3.58231965e-16]
#  [ 1.00000000e+00  3.25485438e-01 -5.99999987e-02 -4.40993667e-01
#    2.22044605e-16 -1.00000000e+00  5.66553869e-16]
#  [ 1.00000000e+00  1.99999996e-02  3.10535550e-01  0.00000000e+00
#   -4.33494806e-01  6.12323426e-17 -1.00000000e+00]
#  [ 1.00000000e+00  2.00032547e-01  1.06142990e-01  5.23132741e-01
#   -9.56575647e-02  9.83689845e-01 -1.79872841e-01]
#  [ 1.00000000e+00 -1.00000001e-01 -3.39909136e-01  4.44089210e-16
#    3.59510303e-01  9.49410749e-16  1.00000000e+00]
#  [ 1.00000000e+00  1.74000636e-01 -1.02901116e-01 -4.66797411e-01
#   -5.15087657e-02 -9.93967056e-01 -1.09679304e-01]
#  [ 1.00000000e+00  5.99999987e-02 -1.47993535e-01  0.00000000e+00
#   -5.47852814e-01  6.12323426e-17 -1.00000000e+00]
#  [ 1.00000000e+00 -1.76702574e-01 -1.08753085e-01 -3.47878486e-01
#    1.35695860e-01 -9.31633472e-01  3.63399327e-01]
#  [ 1.00000000e+00  2.94286944e-02  5.99999987e-02  4.42753166e-01
#   -2.22044605e-16  1.00000000e+00 -5.06261693e-16]
#  [ 1.00000000e+00  1.01277359e-01 -2.97909319e-01 -1.46322139e-02
#   -4.19928193e-01 -3.48234288e-02 -9.99393463e-01]
#  [ 1.00000000e+00 -1.00027680e-01  5.48654139e-01  3.28350201e-04
#    4.98346180e-01  6.58879639e-04  9.99999762e-01]
#  [ 1.00000000e+00 -1.99999996e-02 -8.80741417e-01  2.22044605e-16
#    4.50952500e-01  2.83276934e-16  1.00000000e+00]
#  [ 1.00000000e+00  9.47625756e-01 -5.99999987e-02 -4.96645749e-01
#    0.00000000e+00 -1.00000000e+00  1.22464685e-16]]
# The environment viewer doesn't support agent action rendering.
# c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.vehicle to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.vehicle` for environment variables or `env.get_wrapper_attr('vehicle')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.observation_type to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.observation_type` for environment variables or `env.get_wrapper_attr('observation_type')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.road to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.road` for environment variables or `env.get_wrapper_attr('road')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.vehicle to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.vehicle` for environment variables or `env.get_wrapper_attr('vehicle')` that will search the reminding wrappers.
#   logger.warn(
# Absolute True
# Cheicvle count 15
# Normalizing
# Original df     presence          x          y            vx            vy         cos_h  \
# 0          1  11.406317   7.222438 -9.670902e-01  2.602831e+00  3.482892e-01
# 1          1   6.000000  46.491405  5.342008e-16 -8.724161e+00  6.123234e-17
# 2          1 -39.291867   6.000000  8.752768e+00 -4.431191e-15  1.000000e+00
# 3          1  23.728672  -6.000000 -8.819873e+00  4.996933e-15 -1.000000e+00
# 4          1   2.000000  22.383659  5.308780e-16 -8.669896e+00  6.123234e-17
# 5          1  30.626147  10.125346  1.063184e+01 -3.021761e-01  9.995963e-01
# 6          1 -10.000000 -26.767646  8.477389e-15  7.236630e+00  1.171455e-15
# 7          1  11.008190 -16.609501 -4.636265e+00 -8.171473e+00 -4.934768e-01
# 8          1   6.000000 -25.756409 -6.627939e-15 -1.095706e+01 -6.049015e-16

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 NUM_EPISODES = 10 #@param {type: "integer"}
#       2 evaluation = Evaluation(env, agent, num_episodes=NUM_EPISODES)
# ----> 3 evaluation.test()
#       4 show_videos(evaluation.run_directory)
#
# File ~\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\rl-agents\rl_agents\trainer\evaluation.py:136, in Evaluation.test(self)
#     134 except AttributeError:
#     135     pass
# --> 136 self.run_episodes()
#     137 self.close()
#
# File ~\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\rl-agents\rl_agents\trainer\evaluation.py:148, in Evaluation.run_episodes(self)
#     145 start_time = time.time()
#     146 while not terminal:
#     147     # Step until a terminal step is reached
# --> 148     reward, terminal = self.step()
#     149     rewards.append(reward)
#     151     # Catch interruptions
#
# File ~\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\rl-agents\rl_agents\trainer\evaluation.py:185, in Evaluation.step(self)
#     183 # Step the environment
#     184 previous_observation, action = self.observation, actions[0]
# --> 185 transition = self.wrapped_env.step(action)
#     186 self.observation, reward, done, truncated, info = transition
#     187 terminal = done or truncated
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\wrappers\record_episode_statistics.py:94, in RecordEpisodeStatistics.step(self, action)
#      86 def step(self, action):
#      87     """Steps through the environment, recording the episode statistics."""
#      88     (
#      89         observations,
#      90         rewards,
#      91         terminations,
#      92         truncations,
#      93         infos,
# ---> 94     ) = self.env.step(action)
#      95     assert isinstance(
#      96         infos, dict
#      97     ), f"`info` dtype is {type(infos)} while supported dtype is `dict`. This may be due to usage of other wrappers in the wrong order."
#      98     self.episode_returns += rewards
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\wrappers\record_video.py:166, in RecordVideo.step(self, action)
#     158 def step(self, action):
#     159     """Steps through the environment using action, recording observations if :attr:`self.recording`."""
#     160     (
#     161         observations,
#     162         rewards,
#     163         terminateds,
#     164         truncateds,
#     165         infos,
# --> 166     ) = self.env.step(action)
#     168     if not (self.terminated or self.truncated):
#     169         # increment steps and episodes
#     170         self.step_id += 1
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File c:\Users\jimmy\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\HighwayEnv\highway_env\envs\three_way_intersection.py:151, in ThreeWayIntersectionEnv.step(self, action)
#     150 def step(self, action: int) -> Tuple[np.ndarray, float, bool, bool, dict]:
# --> 151     obs, reward, terminated, truncated, info = super().step(action)
#     152     self._clear_vehicles()
#     153     self._spawn_vehicle(spawn_probability=self.config["spawn_probability"])
#
# File c:\Users\jimmy\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\HighwayEnv\highway_env\envs\common\abstract.py:237, in AbstractEnv.step(self, action)
#     232     raise NotImplementedError(
#     233         "The road and vehicle must be initialized in the environment implementation"
#     234     )
#     236 self.time += 1 / self.config["policy_frequency"]
# --> 237 self._simulate(action)
#     239 obs = self.observation_type.observe()
#     240 reward = self._reward(action)
#
# File c:\Users\jimmy\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\HighwayEnv\highway_env\envs\common\abstract.py:269, in AbstractEnv._simulate(self, action)
#     266     self.action_type.act(action)
#     268 self.road.act()
# --> 269 self.road.step(1 / self.config["simulation_frequency"])
#     270 self.steps += 1
#     272 # Automatically render intermediate simulation steps if a viewer has been launched
#     273 # Ignored if the rendering is done offscreen
#
# File c:\Users\jimmy\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\HighwayEnv\highway_env\road\regulation.py:31, in RegulatedRoad.step(self, dt)
#      29 self.steps += 1
#      30 if self.steps % int(1 / dt / self.REGULATION_FREQUENCY) == 0:
# ---> 31     self.enforce_road_rules()
#      32 return super().step(dt)
#
# File c:\Users\jimmy\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\HighwayEnv\highway_env\road\regulation.py:50, in RegulatedRoad.enforce_road_rules(self)
#      48 for i in range(len(self.vehicles) - 1):
#      49     for j in range(i + 1, len(self.vehicles)):
# ---> 50         if self.is_conflict_possible(self.vehicles[i], self.vehicles[j]):
#      51             yielding_vehicle = self.respect_priorities(
#      52                 self.vehicles[i], self.vehicles[j]
#      53             )
#      54             if (
#      55                 yielding_vehicle is not None
#      56                 and isinstance(yielding_vehicle, ControlledVehicle)
#      57                 and not isinstance(yielding_vehicle, MDPVehicle)
#      58             ):
#
# File c:\Users\jimmy\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\HighwayEnv\highway_env\road\regulation.py:88, in RegulatedRoad.is_conflict_possible(v1, v2, horizon, step)
#      80 @staticmethod
#      81 def is_conflict_possible(
#      82     v1: ControlledVehicle,
#    (...)
#      85     step: float = 0.25,
#      86 ) -> bool:
#      87     times = np.arange(step, horizon, step)
# ---> 88     positions_1, headings_1 = v1.predict_trajectory_constant_speed(times)
#      89     positions_2, headings_2 = v2.predict_trajectory_constant_speed(times)
#      91     for position_1, heading_1, position_2, heading_2 in zip(
#      92         positions_1, headings_1, positions_2, headings_2
#      93     ):
#      94         # Fast spherical pre-check
#
# File c:\Users\jimmy\Documents\Dissertation\Dis1\ThirdYearProject\PettingZooSim\HighwayEnv\highway_env\vehicle\kinematics.py:195, in Vehicle.predict_trajectory_constant_speed(self, times)
#     193 positions = []
#     194 headings = []
# --> 195 v = copy.deepcopy(self)
#     196 v.act(action)
#     197 for t in dt:
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:196, in _deepcopy_list(x, memo, deepcopy)
#     194 append = y.append
#     195 for a in x:
# --> 196     append(deepcopy(a, memo))
#     197 return y
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:276, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     274 if deep:
#     275     for item in listiter:
# --> 276         item = deepcopy(item, memo)
#     277         y.append(item)
#     278 else:
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:253, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     251 if deep and args:
#     252     args = (deepcopy(arg, memo) for arg in args)
# --> 253 y = func(*args)
#     254 if deep:
#     255     memo[id(x)] = y
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:252, in <genexpr>(.0)
#     250 deep = memo is not None
#     251 if deep and args:
# --> 252     args = (deepcopy(arg, memo) for arg in args)
#     253 y = func(*args)
#     254 if deep:
#
# File c:\Users\jimmy\AppData\Local\Programs\Python\Python312\Lib\copy.py:118, in deepcopy(x, memo, _nil)
#     114 d[bytearray] = bytearray.copy
#     116 del d, t
# --> 118 def deepcopy(x, memo=None, _nil=[]):
#     119     """Deep copy operation on arbitrary Python objects.
#     120
#     121     See the module's __doc__ string for more info.
#     122     """
#     124     if memo is None:
#
# KeyboardInterrupt:
