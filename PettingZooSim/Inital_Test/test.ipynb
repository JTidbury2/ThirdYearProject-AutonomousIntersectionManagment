# %%
import gymnasium as gym
import highway_env
from stable_baselines3 import DQN

env = gym.make("highway-fast-v0")
model = DQN('MlpPolicy', env,
              policy_kwargs=dict(net_arch=[256, 256]),
              learning_rate=5e-4,
              buffer_size=15000,
              learning_starts=200,
              batch_size=32,
              gamma=0.8,
              train_freq=1,
              gradient_steps=1,
              target_update_interval=50,
              verbose=1,
              tensorboard_log="highway_dqn/")
model.learn(int(2e4))
model.save("highway_dqn/model")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6        |
# |    ep_rew_mean      | 4.47     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 25       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 24       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.04     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 29       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 97       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.08     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 29       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 131      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 7.33     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 29       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 157      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 7.98     |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 28       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 217      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0684   |
# |    n_updates        | 16       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 7.79     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 27       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 254      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.182    |
# |    n_updates        | 53       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 7.88     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 26       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 297      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0542   |
# |    n_updates        | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 7.42     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 26       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 321      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0911   |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 7.42     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 26       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 362      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.23     |
# |    n_updates        | 161      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.82     |
# |    ep_rew_mean      | 7.23     |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 25       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 393      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.144    |
# |    n_updates        | 192      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 7.47     |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 25       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 444      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.118    |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.9      |
# |    ep_rew_mean      | 7.31     |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 25       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 475      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.457    |
# |    n_updates        | 274      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 7.41     |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 25       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 521      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.224    |
# |    n_updates        | 320      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 7.47     |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 24       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 561      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0854   |
# |    n_updates        | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.93     |
# |    ep_rew_mean      | 7.41     |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 23       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 596      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.37     |
# |    n_updates        | 395      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 7.49     |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 23       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 644      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.326    |
# |    n_updates        | 443      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.94     |
# |    ep_rew_mean      | 7.39     |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 23       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 676      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.28     |
# |    n_updates        | 475      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 7.48     |
# |    exploration_rate | 0.655    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 22       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 726      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.344    |
# |    n_updates        | 525      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 7.46     |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 22       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 764      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.178    |
# |    n_updates        | 563      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 7.45     |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 22       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 802      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0248   |
# |    n_updates        | 601      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.06     |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 22       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 910      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.329    |
# |    n_updates        | 709      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 8.6      |
# |    exploration_rate | 0.517    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 22       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 1017     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.164    |
# |    n_updates        | 816      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.85     |
# |    exploration_rate | 0.482    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 22       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 1091     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.292    |
# |    n_updates        | 890      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.88     |
# |    exploration_rate | 0.458    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 22       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 1141     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.196    |
# |    n_updates        | 940      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.91     |
# |    exploration_rate | 0.432    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 22       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 1195     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.358    |
# |    n_updates        | 994      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.13     |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 22       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 1248     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0254   |
# |    n_updates        | 1047     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 8.93     |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 22       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 1297     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.171    |
# |    n_updates        | 1096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 9.36     |
# |    exploration_rate | 0.341    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 22       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 1388     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.305    |
# |    n_updates        | 1187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 9.55     |
# |    exploration_rate | 0.316    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 21       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 1440     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.119    |
# |    n_updates        | 1239     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.259    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 21       |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 1560     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.363    |
# |    n_updates        | 1359     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.221    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 21       |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 1640     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0261   |
# |    n_updates        | 1439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.164    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 21       |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 1760     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0306   |
# |    n_updates        | 1559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.127    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 21       |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 1837     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.108    |
# |    n_updates        | 1636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.106    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 21       |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 1883     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0997   |
# |    n_updates        | 1682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.0718   |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 21       |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 1954     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0298   |
# |    n_updates        | 1753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 21       |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 2036     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.088    |
# |    n_updates        | 1835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 21       |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 2127     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0197   |
# |    n_updates        | 1926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 21       |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 2191     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.135    |
# |    n_updates        | 1990     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 21       |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 2281     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.144    |
# |    n_updates        | 2080     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 21       |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 2358     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 2157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 21       |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 2401     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.203    |
# |    n_updates        | 2200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 21       |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 2461     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.224    |
# |    n_updates        | 2260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 21       |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 2521     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.08     |
# |    n_updates        | 2320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 21       |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 2552     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.171    |
# |    n_updates        | 2351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 21       |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 2593     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.204    |
# |    n_updates        | 2392     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 21       |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 2668     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.16     |
# |    n_updates        | 2467     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 21       |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 2707     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.205    |
# |    n_updates        | 2506     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 21       |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 2768     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.276    |
# |    n_updates        | 2567     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 21       |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 2838     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.121    |
# |    n_updates        | 2637     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 21       |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 2890     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.194    |
# |    n_updates        | 2689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 21       |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 2970     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.193    |
# |    n_updates        | 2769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 21       |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 3021     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.019    |
# |    n_updates        | 2820     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 21       |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 3060     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.242    |
# |    n_updates        | 2859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 20       |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 3129     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.269    |
# |    n_updates        | 2928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 20       |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 3188     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0756   |
# |    n_updates        | 2987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 20       |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 3259     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.146    |
# |    n_updates        | 3058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 20       |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 3297     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.209    |
# |    n_updates        | 3096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 20       |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 3380     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.275    |
# |    n_updates        | 3179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 20       |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 3450     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.166    |
# |    n_updates        | 3249     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 20       |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 3482     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0961   |
# |    n_updates        | 3281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 20       |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 3559     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0475   |
# |    n_updates        | 3358     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 20       |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 3644     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 3443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 20       |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 3696     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0415   |
# |    n_updates        | 3495     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 20       |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 3761     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.411    |
# |    n_updates        | 3560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 20       |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 3799     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.186    |
# |    n_updates        | 3598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 20       |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 3883     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.241    |
# |    n_updates        | 3682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 20       |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 3955     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0958   |
# |    n_updates        | 3754     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 20       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 4028     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.186    |
# |    n_updates        | 3827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 20       |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 4112     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.149    |
# |    n_updates        | 3911     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 20       |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 4184     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.222    |
# |    n_updates        | 3983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 20       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 4223     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.173    |
# |    n_updates        | 4022     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 20       |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 4304     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.102    |
# |    n_updates        | 4103     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 20       |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 4365     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0261   |
# |    n_updates        | 4164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 20       |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 4439     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0192   |
# |    n_updates        | 4238     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.5     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 20       |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 4539     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.12     |
# |    n_updates        | 4338     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 20       |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 4592     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0788   |
# |    n_updates        | 4391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 20       |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 4712     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.254    |
# |    n_updates        | 4511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 20       |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 4794     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.249    |
# |    n_updates        | 4593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 20       |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 4900     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0939   |
# |    n_updates        | 4699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 20       |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 4956     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.168    |
# |    n_updates        | 4755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 20       |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 5054     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.129    |
# |    n_updates        | 4853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 20       |
# |    time_elapsed     | 254      |
# |    total_timesteps  | 5149     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.194    |
# |    n_updates        | 4948     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 20       |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 5226     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0844   |
# |    n_updates        | 5025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 20       |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 5346     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0984   |
# |    n_updates        | 5145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 20       |
# |    time_elapsed     | 269      |
# |    total_timesteps  | 5442     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0731   |
# |    n_updates        | 5241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 20       |
# |    time_elapsed     | 273      |
# |    total_timesteps  | 5537     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.102    |
# |    n_updates        | 5336     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 20       |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 5610     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.107    |
# |    n_updates        | 5409     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.3     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 20       |
# |    time_elapsed     | 283      |
# |    total_timesteps  | 5726     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0976   |
# |    n_updates        | 5525     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 20       |
# |    time_elapsed     | 288      |
# |    total_timesteps  | 5826     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0733   |
# |    n_updates        | 5625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 20       |
# |    time_elapsed     | 292      |
# |    total_timesteps  | 5911     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0195   |
# |    n_updates        | 5710     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 20       |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 6023     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0146   |
# |    n_updates        | 5822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 20       |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 6125     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.183    |
# |    n_updates        | 5924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# ...
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0405   |
# |    n_updates        | 8619     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.1     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 20       |
# |    time_elapsed     | 445      |
# |    total_timesteps  | 8940     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0562   |
# |    n_updates        | 8739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.5     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 20       |
# |    time_elapsed     | 449      |
# |    total_timesteps  | 9003     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.127    |
# |    n_updates        | 8802     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 20       |
# |    time_elapsed     | 455      |
# |    total_timesteps  | 9117     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0204   |
# |    n_updates        | 8916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26       |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 20       |
# |    time_elapsed     | 461      |
# |    total_timesteps  | 9237     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.207    |
# |    n_updates        | 9036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.1     |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 20       |
# |    time_elapsed     | 466      |
# |    total_timesteps  | 9335     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0169   |
# |    n_updates        | 9134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 20       |
# |    time_elapsed     | 471      |
# |    total_timesteps  | 9439     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0688   |
# |    n_updates        | 9238     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 20       |
# |    time_elapsed     | 476      |
# |    total_timesteps  | 9545     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0101   |
# |    n_updates        | 9344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.3     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 20       |
# |    time_elapsed     | 482      |
# |    total_timesteps  | 9650     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.265    |
# |    n_updates        | 9449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.5     |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 19       |
# |    time_elapsed     | 487      |
# |    total_timesteps  | 9752     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.154    |
# |    n_updates        | 9551     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.1     |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 19       |
# |    time_elapsed     | 492      |
# |    total_timesteps  | 9837     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.119    |
# |    n_updates        | 9636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.4     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 19       |
# |    time_elapsed     | 495      |
# |    total_timesteps  | 9885     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.142    |
# |    n_updates        | 9684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.8     |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 19       |
# |    time_elapsed     | 501      |
# |    total_timesteps  | 10005    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0132   |
# |    n_updates        | 9804     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.8     |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 19       |
# |    time_elapsed     | 506      |
# |    total_timesteps  | 10106    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0265   |
# |    n_updates        | 9905     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.8     |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 19       |
# |    time_elapsed     | 513      |
# |    total_timesteps  | 10226    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0181   |
# |    n_updates        | 10025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.9     |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 19       |
# |    time_elapsed     | 518      |
# |    total_timesteps  | 10328    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0281   |
# |    n_updates        | 10127    |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#       5 env = gym.make("highway-fast-v0")
#       6 model = DQN('MlpPolicy', env,
#       7               policy_kwargs=dict(net_arch=[256, 256]),
#       8               learning_rate=5e-4,
#    (...)
#      16               verbose=1,
#      17               tensorboard_log="highway_dqn/")
# ---> 18 model.learn(int(2e4))
#      19 model.save("highway_dqn/model")
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\stable_baselines3\dqn\dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\highway_env\envs\common\abstract.py:235, in AbstractEnv.step(self, action)
#     232     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     234 self.time += 1 / self.config["policy_frequency"]
# --> 235 self._simulate(action)
#     237 obs = self.observation_type.observe()
#     238 reward = self._reward(action)
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\highway_env\envs\common\abstract.py:257, in AbstractEnv._simulate(self, action)
#     252 if action is not None \
#     253         and not self.config["manual_control"] \
#     254         and self.steps % int(self.config["simulation_frequency"] // self.config["policy_frequency"]) == 0:
#     255     self.action_type.act(action)
# --> 257 self.road.act()
#     258 self.road.step(1 / self.config["simulation_frequency"])
#     259 self.steps += 1
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\highway_env\road\road.py:324, in Road.act(self)
#     322 """Decide the actions of each entity on the road."""
#     323 for vehicle in self.vehicles:
# --> 324     vehicle.act()
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\highway_env\vehicle\behavior.py:100, in IDMVehicle.act(self, action)
#      97 action['steering'] = np.clip(action['steering'], -self.MAX_STEERING_ANGLE, self.MAX_STEERING_ANGLE)
#      99 # Longitudinal: IDM
# --> 100 front_vehicle, rear_vehicle = self.road.neighbour_vehicles(self, self.lane_index)
#     101 action['acceleration'] = self.acceleration(ego_vehicle=self,
#     102                                            front_vehicle=front_vehicle,
#     103                                            rear_vehicle=rear_vehicle)
#     104 # When changing lane, check both current and target lanes
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\highway_env\road\road.py:355, in Road.neighbour_vehicles(self, vehicle, lane_index)
#     353     return None, None
#     354 lane = self.network.get_lane(lane_index)
# --> 355 s = self.network.get_lane(lane_index).local_coordinates(vehicle.position)[0]
#     356 s_front = s_rear = None
#     357 v_front = v_rear = None
#
# File c:\Users\jimmy\OneDrive\Documents\Uni\3rd Year\Project\FinalSimulation\.venv\Lib\site-packages\highway_env\road\lane.py:189, in StraightLane.local_coordinates(self, position)
#     187 def local_coordinates(self, position: np.ndarray) -> Tuple[float, float]:
#     188     delta = position - self.start
# --> 189     longitudinal = np.dot(delta, self.direction)
#     190     lateral = np.dot(delta, self.direction_lateral)
#     191     return float(longitudinal), float(lateral)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
